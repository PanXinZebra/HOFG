# %%
from skimage.io import *;
from SegHelperV2 import *;
from skimage.segmentation import felzenszwalb, slic, quickshift, watershed, join_segmentations
from skimage.segmentation import mark_boundaries
from DeepSegment import *;

import torch
print(torch.__version__);
# Out:
# 1.7.1

# %%
#create "Grid"
thesegments= 800;
thecompactness=10;
imagefile=r".\\imgs\\test1.bmp";
gridresult=r".\\results\\grid.bmp";
image=imread(imagefile);
image=image[:,:,0:3];
nmimage=image/255;
segments=slic(image,n_segments=thesegments,compactness=thecompactness,start_label=0);
seghelper=SegHelperV2();
seghelper.readSegments(segments);
bd=mark_boundaries(image/255, segments);
imshow(bd);
imsave(gridresult,bd)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
#Perform HOFG
thesavestepimgpath=".\\results\\"
mingrids=3;
result=runDeepSeg(seghelper,image,maxiter=4,savestepimg=True, savestepimgpath=thesavestepimgpath,theMinGrids=mingrids);
bd=mark_boundaries(nmimage, result,mode='thick');
imshow(bd);
resultpath=".\\results\\ZI-HOFG.bmp"
imsave(resultpath,bd)
resultnpz=".\\results\\ZS-HOFG";
np.save(resultnpz,result);
# Out:
# Run[ 000 ]
# D:\ProgramData\Anaconda3\envs\pytorch\lib\site-packages\skimage\exposure\exposure.py:181: UserWarning: This might be a color image. The histogram will be computed on the flattened image. You can instead apply this function to each color channel.
#   hist, bin_centers = histogram(image, nbins)
# D:\ProgramData\Anaconda3\envs\pytorch\lib\site-packages\torch\nn\_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='mean' instead.
#   warnings.warn(warning.format(ret))
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Gounp NUM=3,Break decsion 0-->54
# Gounp NUM=3,Break decsion 0-->55
# Gounp NUM=2,Break decsion 2-->56
# Gounp NUM=2,Break decsion 4-->57
# Gounp NUM=2,Break decsion 23-->58
# Gounp NUM=2,Break decsion 27-->59
# Run[ 001 ]
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Gounp NUM=2,Break decsion 4-->132
# Gounp NUM=2,Break decsion 7-->133
# Gounp NUM=4,Break decsion 11-->134
# Gounp NUM=4,Break decsion 11-->135
# Gounp NUM=4,Break decsion 11-->136
# Gounp NUM=13,Break decsion 14-->137
# Gounp NUM=13,Break decsion 14-->138
# Gounp NUM=13,Break decsion 14-->139
# Gounp NUM=13,Break decsion 14-->140
# Gounp NUM=13,Break decsion 14-->141
# Gounp NUM=13,Break decsion 14-->142
# Gounp NUM=13,Break decsion 14-->143
# Gounp NUM=13,Break decsion 14-->144
# Gounp NUM=13,Break decsion 14-->145
# Gounp NUM=13,Break decsion 14-->146
# Gounp NUM=13,Break decsion 14-->147
# Gounp NUM=13,Break decsion 14-->148
# Gounp NUM=7,Break decsion 20-->149
# Gounp NUM=7,Break decsion 20-->150
# Gounp NUM=7,Break decsion 20-->151
# Gounp NUM=7,Break decsion 20-->152
# Gounp NUM=7,Break decsion 20-->153
# Gounp NUM=7,Break decsion 20-->154
# Gounp NUM=5,Break decsion 24-->155
# Gounp NUM=5,Break decsion 24-->156
# Gounp NUM=5,Break decsion 24-->157
# Gounp NUM=5,Break decsion 24-->158
# Gounp NUM=2,Break decsion 28-->159
# Gounp NUM=2,Break decsion 52-->160
# Gounp NUM=3,Break decsion 59-->161
# Gounp NUM=3,Break decsion 59-->162
# Gounp NUM=2,Break decsion 64-->163
# Gounp NUM=7,Break decsion 69-->164
# Gounp NUM=7,Break decsion 69-->165
# Gounp NUM=7,Break decsion 69-->166
# Gounp NUM=7,Break decsion 69-->167
# Gounp NUM=7,Break decsion 69-->168
# Gounp NUM=7,Break decsion 69-->169
# Gounp NUM=2,Break decsion 73-->170
# Gounp NUM=2,Break decsion 78-->171
# Gounp NUM=2,Break decsion 79-->172
# Gounp NUM=3,Break decsion 82-->173
# Gounp NUM=3,Break decsion 82-->174
# Gounp NUM=2,Break decsion 94-->175
# Gounp NUM=2,Break decsion 130-->176
# Run[ 002 ]
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Gounp NUM=2,Break decsion 5-->274
# Gounp NUM=7,Break decsion 6-->275
# Gounp NUM=7,Break decsion 6-->276
# Gounp NUM=7,Break decsion 6-->277
# Gounp NUM=7,Break decsion 6-->278
# Gounp NUM=7,Break decsion 6-->279
# Gounp NUM=7,Break decsion 6-->280
# Gounp NUM=2,Break decsion 26-->281
# Gounp NUM=2,Break decsion 29-->282
# Gounp NUM=2,Break decsion 32-->283
# Gounp NUM=3,Break decsion 92-->284
# Gounp NUM=3,Break decsion 92-->285
# Gounp NUM=4,Break decsion 93-->286
# Gounp NUM=4,Break decsion 93-->287
# Gounp NUM=4,Break decsion 93-->288
# Gounp NUM=2,Break decsion 107-->289
# Gounp NUM=2,Break decsion 113-->290
# Gounp NUM=2,Break decsion 114-->291
# Gounp NUM=4,Break decsion 131-->292
# Gounp NUM=4,Break decsion 131-->293
# Gounp NUM=4,Break decsion 131-->294
# Gounp NUM=2,Break decsion 136-->295
# Gounp NUM=2,Break decsion 150-->296
# Gounp NUM=2,Break decsion 158-->297
# Gounp NUM=2,Break decsion 162-->298
# Gounp NUM=2,Break decsion 164-->299
# Gounp NUM=4,Break decsion 171-->300
# Gounp NUM=4,Break decsion 171-->301
# Gounp NUM=4,Break decsion 171-->302
# Gounp NUM=2,Break decsion 172-->303
# Gounp NUM=2,Break decsion 183-->304
# Gounp NUM=2,Break decsion 186-->305
# Gounp NUM=2,Break decsion 201-->306
# Gounp NUM=2,Break decsion 207-->307
# Gounp NUM=2,Break decsion 216-->308
# Gounp NUM=2,Break decsion 248-->309
# Run[ 003 ]
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Gounp NUM=2,Break decsion 88-->453
# Gounp NUM=2,Break decsion 108-->454
# Gounp NUM=2,Break decsion 255-->455
# Gounp NUM=2,Break decsion 363-->456
# Gounp NUM=2,Break decsion 400-->457
# Gounp NUM=2,Break decsion 414-->458
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
#result of iteration=1
timage=imread(thesavestepimgpath+"\\001.bmp");
imshow(timage);

# %%
#result of iteration=2
timage=imread(thesavestepimgpath+"\\002.bmp");
imshow(timage);

# %%
#result of iteration=3
timage=imread(thesavestepimgpath+"\\003.bmp");
imshow(timage);

# %%
#result of iteration=4
timage=imread(thesavestepimgpath+"\\004.bmp");
imshow(timage);
